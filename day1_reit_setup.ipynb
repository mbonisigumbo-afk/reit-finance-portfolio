# %%
import sys
import pandas as pd
import numpy as np

print("Python Version:", sys.version)
print("Pandas Version:", pd.__version__)
print("NumPy Version:", np.__version__)
# Out:
# Python Version: 3.13.11 | packaged by Anaconda, Inc. | (main, Dec 10 2025, 21:21:58) [MSC v.1929 64 bit (AMD64)]
# Pandas Version: 3.0.2
# NumPy Version: 2.4.4

# %%
print("REIT Finance Engineering Journey Started 🚀")
# Out:
# REIT Finance Engineering Journey Started 🚀

# %%
reit_name = "Hyprop Investments Ltd"
occupancy_rate = 97.52
net_income = 1242824000 
total_assets = 32005777000

print("REIT:", reit_name)
print("Occupancy Rate:", occupancy_rate, "%")
print("Net Income:", net_income)
print("Total Assets:", total_assets)
# Out:
# REIT: Hyprop Investments Ltd
# Occupancy Rate: 97.52 %
# Net Income: 1242824000
# Total Assets: 32005777000

# %%
return_on_assets = net_income / total_assets

print("ROA:", round(return_on_assets, 2))
# Out:
# ROA: 0.04
